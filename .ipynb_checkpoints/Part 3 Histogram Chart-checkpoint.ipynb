# %% [markdown]
# # Histogram Plot

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

x=np.random.randint(10,60,50)
print(x)
# Out:
# [33 29 56 22 41 41 22 51 49 16 49 59 24 51 26 47 38 29 59 19 44 11 31 54
#  41 49 54 28 30 31 19 30 13 25 56 22 49 48 49 51 11 40 27 49 30 59 31 12
#  15 44]

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
plt.hist(no)
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
plt.hist(no,color="g")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
plt.hist(no,color="g",edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",bins=l,edgecolor="r")
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",cumulative=-1)
plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",bottom=20)

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",align="mid")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",histtype="step")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",orientation="horizontal")

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",rwidth=0.8)

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",log=True)

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",label='python')

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")
plt.legend()
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",label='python')

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")

plt.axvline(45,color="b",label="line")

plt.legend()
plt.show()

# %%
no=[33, 29, 56, 22, 41, 41, 22, 51, 49, 16, 49, 59, 24, 51, 26, 47, 38, 29, 59, 19, 44, 11, 31, 54,
 41, 49, 54, 28, 30, 31, 19, 30, 13, 25, 56, 22, 49, 48, 49, 51, 11, 40, 27, 49, 30, 59, 31, 12,
 15, 44]
l=[10,20,30,40,50,60]
plt.hist(no,color="g",edgecolor="r",label='python')

plt.title("Histogram")
plt.xlabel("Python")
plt.ylabel("No.")

plt.axvline(45,color="b",label="line")

plt.legend()
plt.grid()
plt.show()
